# %%
from google.colab import drive
drive.mount('/content/drive')

# Change this path to where your ZIP is stored in Drive
zip_path = "/content/drive/MyDrive/emotion-recognition-using-speech-master.zip"

# Unzip into /content
# !unzip -q "$zip_path" -d /content/
# Out:
# Mounted at /content/drive

# %%
# set repo dir (change if different)
REPO_DIR = "/content/emotion-recognition-using-speech-master"
# %cd "$REPO_DIR"
# !ls -la
# Out:
# /content/emotion-recognition-using-speech-master
# total 148
# drwxr-xr-x 7 root root  4096 Apr 30  2023 .
# drwxr-xr-x 1 root root  4096 Aug 26 16:46 ..
# -rw-r--r-- 1 root root  1290 Apr 30  2023 CITATION.cff
# -rw-r--r-- 1 root root  3232 Apr 30  2023 convert_wavs.py
# -rw-r--r-- 1 root root  5767 Apr 30  2023 create_csv.py
# drwxr-xr-x 7 root root  4096 Apr 30  2023 data
# -rw-r--r-- 1 root root 11327 Apr 30  2023 data_extractor.py
# -rw-r--r-- 1 root root 17746 Apr 30  2023 deep_emotion_recognition.py
# -rw-r--r-- 1 root root 22338 Apr 30  2023 emotion_recognition.py
# drwxr-xr-x 2 root root  4096 Apr 30  2023 features
# -rw-r--r-- 1 root root    66 Apr 30  2023 .gitattributes
# drwxr-xr-x 2 root root  4096 Apr 30  2023 grid
# -rw-r--r-- 1 root root  3079 Apr 30  2023 grid_search.py
# drwxr-xr-x 2 root root  4096 Apr 30  2023 images
# -rw-r--r-- 1 root root  1064 Apr 30  2023 LICENSE
# drwxr-xr-x 5 root root  4096 Apr 30  2023 logs
# -rw-r--r-- 1 root root  3168 Apr 30  2023 parameters.py
# -rw-r--r-- 1 root root 11875 Apr 30  2023 README.md
# -rw-r--r-- 1 root root   135 Apr 30  2023 requirements.txt
# -rw-r--r-- 1 root root  5022 Apr 30  2023 test.py
# -rw-r--r-- 1 root root  4375 Apr 30  2023 utils.py

# %%
# !pip install -q librosa==0.10.1 soundfile tensorflow==2.16.1 matplotlib scikit-learn seaborn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.9/589.9 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 65.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 110.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 121.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.16.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.5.3 requires ml_dtypes>=0.4.0, but you have ml-dtypes 0.3.2 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.16.1 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# tensorstore 0.1.76 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.3.2 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.16.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# !pip install librosa==0.8.1
# Out:
# Requirement already satisfied: librosa==0.8.1 in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (3.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.16.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.5.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (0.4.3)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (0.60.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.43.0->librosa==0.8.1) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.8.1) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.8.1) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.2->librosa==0.8.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.8.1) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (2025.8.3)

# %%
# !pip install soundfile==0.10.3.post1
# Out:
# Collecting soundfile==0.10.3.post1
#   Using cached SoundFile-0.10.3.post1-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile==0.10.3.post1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile==0.10.3.post1) (2.22)
# Using cached SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: soundfile
#   Attempting uninstall: soundfile
#     Found existing installation: soundfile 0.13.1
#     Uninstalling soundfile-0.13.1:
#       Successfully uninstalled soundfile-0.13.1
# Successfully installed soundfile-0.10.3.post1

# %%
# !pip install scikit-learn==1.0.2
# Out:
# Collecting scikit-learn==1.0.2
#   Downloading scikit-learn-1.0.2.tar.gz (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 42.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install pandas==1.3.5
# Out:
# Collecting pandas==1.3.5
#   Downloading pandas-1.3.5.tar.gz (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 56.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from pandas==1.3.5) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pandas==1.3.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.12/dist-packages (from pandas==1.3.5) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.17.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... done
#   Created wheel for pandas: filename=pandas-1.3.5-cp312-cp312-linux_x86_64.whl size=40409637 sha256=4cfa2e4749fee726dad17463f2665bee2766988bd06d98f93be7a27da27bddf2
#   Stored in directory: /root/.cache/pip/wheels/e3/15/7f/43571d4c48966d63f4f7a640e9345b57e23f1656d4d5b81b16
# Successfully built pandas
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.3.5 which is incompatible.
# bigframes 2.15.0 requires pandas>=1.5.3, but you have pandas 1.3.5 which is incompatible.
# arviz 0.22.0 requires pandas>=2.1.0, but you have pandas 1.3.5 which is incompatible.
# libpysal 4.13.0 requires pandas>=1.4, but you have pandas 1.3.5 which is incompatible.
# db-dtypes 1.4.3 requires pandas>=1.5.3, but you have pandas 1.3.5 which is incompatible.
# geopandas 1.1.1 requires pandas>=2.0.0, but you have pandas 1.3.5 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 1.3.5 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 1.3.5 which is incompatible.
# statsmodels 0.14.5 requires pandas!=2.1.0,>=1.4, but you have pandas 1.3.5 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.3.5 which is incompatible.
# xarray 2025.8.0 requires pandas>=2.2, but you have pandas 1.3.5 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.16.1 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.3.5 which is incompatible.
# Successfully installed pandas-1.3.5

# %%
# !pip install numpy==1.21.6
# Out:
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement numpy==1.21.6 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4, 1.25.0, 1.25.1, 1.25.2, 1.26.0, 1.26.1, 1.26.2, 1.26.3, 1.26.4, 2.0.0, 2.0.1, 2.0.2, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.2.6, 2.3.0, 2.3.1, 2.3.2)
# ERROR: No matching distribution found for numpy==1.21.6

# %%
# !ls -lh
# Out:
# total 136K
# -rw-r--r-- 1 root root 1.3K Apr 30  2023 CITATION.cff
# -rw-r--r-- 1 root root 3.2K Apr 30  2023 convert_wavs.py
# -rw-r--r-- 1 root root 5.7K Apr 30  2023 create_csv.py
# drwxr-xr-x 7 root root 4.0K Apr 30  2023 data
# -rw-r--r-- 1 root root  12K Apr 30  2023 data_extractor.py
# -rw-r--r-- 1 root root  18K Apr 30  2023 deep_emotion_recognition.py
# -rw-r--r-- 1 root root  22K Apr 30  2023 emotion_recognition.py
# drwxr-xr-x 2 root root 4.0K Apr 30  2023 features
# drwxr-xr-x 2 root root 4.0K Apr 30  2023 grid
# -rw-r--r-- 1 root root 3.1K Apr 30  2023 grid_search.py
# drwxr-xr-x 2 root root 4.0K Apr 30  2023 images
# -rw-r--r-- 1 root root 1.1K Apr 30  2023 LICENSE
# drwxr-xr-x 5 root root 4.0K Apr 30  2023 logs
# -rw-r--r-- 1 root root 3.1K Apr 30  2023 parameters.py
# -rw-r--r-- 1 root root  12K Apr 30  2023 README.md
# -rw-r--r-- 1 root root  135 Apr 30  2023 requirements.txt
# -rw-r--r-- 1 root root 5.0K Apr 30  2023 test.py
# -rw-r--r-- 1 root root 4.3K Apr 30  2023 utils.py

# %%
pip install numpy==1.26.4 pandas==1.3.5 librosa==0.8.1 soundfile==0.10.3.post1 scikit-learn==1.3.2
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: pandas==1.3.5 in /usr/local/lib/python3.12/dist-packages (1.3.5)
# Requirement already satisfied: librosa==0.8.1 in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: soundfile==0.10.3.post1 in /usr/local/lib/python3.12/dist-packages (0.10.3.post1)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from pandas==1.3.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.12/dist-packages (from pandas==1.3.5) (2025.2)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (3.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.16.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.5.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (0.4.3)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (0.60.0)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.8.1) (25.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile==0.10.3.post1) (1.17.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.3.2) (3.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile==0.10.3.post1) (2.22)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.43.0->librosa==0.8.1) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.8.1) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.8.1) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.1) (2025.8.3)

# %%
pip install --upgrade librosa==0.10.1
# Out:
# Collecting librosa==0.10.1
#   Using cached librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (1.16.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (1.3.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (0.60.0)
# Collecting soundfile>=0.12.1 (from librosa==0.10.1)
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (4.14.1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.10.1) (1.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy-loader>=0.1->librosa==0.10.1) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa==0.10.1) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.10.1) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.10.1) (2.32.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->librosa==0.10.1) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa==0.10.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.1) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.1) (2025.8.3)
# Using cached librosa-0.10.1-py3-none-any.whl (253 kB)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: soundfile, librosa
#   Attempting uninstall: soundfile
#     Found existing installation: SoundFile 0.10.3.post1
#     Uninstalling SoundFile-0.10.3.post1:
#       Successfully uninstalled SoundFile-0.10.3.post1
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# Successfully installed librosa-0.10.1 soundfile-0.13.1

# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
DATA_PATH = "/content/emotion-recognition-using-speech-master/data/training"

# %%
import os
print("Files in DATA_PATH:", os.listdir(DATA_PATH))
# Out:
# Files in DATA_PATH: ['Actor_23', 'Actor_02', 'Actor_15', 'Actor_03', 'Actor_19', 'Actor_07', 'Actor_09', 'Actor_18', 'Actor_26', 'Actor_20', 'Actor_17', 'Actor_13', 'Actor_14', 'Actor_04', 'Actor_01', 'Actor_21', 'Actor_12', 'Actor_25', 'Actor_22', 'Actor_10', 'Actor_16', 'Actor_08', 'Actor_11', 'Actor_05', 'Actor_24', 'Actor_06']

# %%
def extract_features(file_path, max_pad_len=174):
    try:
        audio, sr = librosa.load(file_path, sr=22050)  # load audio
        mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)

        # Pad/truncate to fixed length
        if mfccs.shape[1] < max_pad_len:
            pad_width = max_pad_len - mfccs.shape[1]
            mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            mfccs = mfccs[:, :max_pad_len]

        return mfccs
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# %%
labels = []
features = []

for root, dirs, files in os.walk(DATA_PATH):
    for file in files:
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)

            # Extract features
            data = extract_features(file_path)

            if data is not None:
                features.append(data)
                # Label = Actor_xx
                labels.append(os.path.basename(root))

X = np.array(features)
y = np.array(labels)

print("✅ Features shape:", X.shape)
print("✅ Labels shape:", y.shape)
# Out:
# ✅ Features shape: (5202, 40, 174)
# ✅ Labels shape: (5202,)

# %%
print("Features shape:", X.shape)
print("Labels shape:", y.shape)
print("Unique labels:", np.unique(y))
# Out:
# Features shape: (5202, 40, 174)
# Labels shape: (5202,)
# Unique labels: ['Actor_01' 'Actor_02' 'Actor_03' 'Actor_04' 'Actor_05' 'Actor_06'
#  'Actor_07' 'Actor_08' 'Actor_09' 'Actor_10' 'Actor_11' 'Actor_12'
#  'Actor_13' 'Actor_14' 'Actor_15' 'Actor_16' 'Actor_17' 'Actor_18'
#  'Actor_19' 'Actor_20' 'Actor_21' 'Actor_22' 'Actor_23' 'Actor_24'
#  'Actor_25' 'Actor_26']

# %%
# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# --- Save with SER-specific names ---
X_ser_train, X_ser_test = X_train, X_test
y_ser_train, y_ser_test = y_train, y_test

# %%
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from tensorflow.keras.models import Sequential

model = Sequential([
    Input(shape=(40, 174)),   # 40 timesteps, 174 features
    LSTM(128, return_sequences=True),
    Dropout(0.3),
    LSTM(64),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(len(np.unique(y_encoded)), activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 40, 128)        │       155,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 26)             │         1,690 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 210,394 (821.85 KB)
#  Trainable params: 210,394 (821.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.3579 - loss: 2.3578 - val_accuracy: 0.5485 - val_loss: 1.6198
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5686 - loss: 1.4907 - val_accuracy: 0.6340 - val_loss: 1.1939
# Epoch 3/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6424 - loss: 1.1173 - val_accuracy: 0.6407 - val_loss: 1.0643
# Epoch 4/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6846 - loss: 0.9262 - val_accuracy: 0.6888 - val_loss: 0.9433
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7296 - loss: 0.7738 - val_accuracy: 0.7224 - val_loss: 0.8925
# Epoch 6/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7666 - loss: 0.7036 - val_accuracy: 0.7608 - val_loss: 0.8212
# Epoch 7/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8149 - loss: 0.5533 - val_accuracy: 0.7474 - val_loss: 0.8144
# Epoch 8/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7946 - loss: 0.6297 - val_accuracy: 0.7646 - val_loss: 0.7992
# Epoch 9/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8516 - loss: 0.4528 - val_accuracy: 0.7819 - val_loss: 0.7609
# Epoch 10/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8672 - loss: 0.4011 - val_accuracy: 0.7819 - val_loss: 0.7749
# Epoch 11/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8705 - loss: 0.4245 - val_accuracy: 0.7791 - val_loss: 0.7641
# Epoch 12/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8612 - loss: 0.4168 - val_accuracy: 0.7954 - val_loss: 0.7651
# Epoch 13/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9051 - loss: 0.2849 - val_accuracy: 0.7983 - val_loss: 0.7543
# Epoch 14/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9411 - loss: 0.2106 - val_accuracy: 0.8175 - val_loss: 0.7418
# Epoch 15/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9471 - loss: 0.1832 - val_accuracy: 0.7896 - val_loss: 0.8190
# Epoch 16/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9369 - loss: 0.1919 - val_accuracy: 0.7963 - val_loss: 0.8113
# Epoch 17/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9417 - loss: 0.1929 - val_accuracy: 0.8031 - val_loss: 0.7977
# Epoch 18/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9506 - loss: 0.1666 - val_accuracy: 0.8031 - val_loss: 0.8175
# Epoch 19/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9417 - loss: 0.1845 - val_accuracy: 0.8060 - val_loss: 0.8306
# Epoch 20/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9553 - loss: 0.1462 - val_accuracy: 0.8098 - val_loss: 0.8528
# Epoch 21/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9621 - loss: 0.1320 - val_accuracy: 0.8165 - val_loss: 0.8327
# Epoch 22/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9616 - loss: 0.1241 - val_accuracy: 0.8079 - val_loss: 0.8550
# Epoch 23/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9590 - loss: 0.1166 - val_accuracy: 0.8012 - val_loss: 0.8774
# Epoch 24/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9644 - loss: 0.1123 - val_accuracy: 0.8050 - val_loss: 0.9457
# Epoch 25/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9713 - loss: 0.0971 - val_accuracy: 0.8098 - val_loss: 0.8721
# Epoch 26/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9750 - loss: 0.0860 - val_accuracy: 0.7963 - val_loss: 0.9463
# Epoch 27/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9458 - loss: 0.1752 - val_accuracy: 0.8213 - val_loss: 0.8074
# Epoch 28/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9627 - loss: 0.1242 - val_accuracy: 0.7973 - val_loss: 0.8930
# Epoch 29/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9690 - loss: 0.1033 - val_accuracy: 0.8069 - val_loss: 0.8894
# Epoch 30/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9796 - loss: 0.0725 - val_accuracy: 0.8060 - val_loss: 0.9651

# %%
# 2. Evaluate on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"✅ Test Accuracy: {test_acc:.4f}")
print(f"✅ Test Loss: {test_loss:.4f}")
# Out:
# ✅ Test Accuracy: 0.8060
# ✅ Test Loss: 0.9651

# %%
import matplotlib.pyplot as plt

# Graph 1: Training & Validation Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Graph 2: Training & Validation Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Training vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predictions
y_pred = model.predict(X_test)
y_pred_classes = y_pred.argmax(axis=1)

# If y_test is already integer labels
y_true = y_test

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Training accuracy (last epoch)
train_acc = history.history['accuracy'][-1]

# Validation accuracy (last epoch)
val_acc = history.history['val_accuracy'][-1]

print(f"Final Training Accuracy: {train_acc:.4f} ({train_acc*100:.2f}%)")
print(f"Final Validation Accuracy: {val_acc:.4f} ({val_acc*100:.2f}%)")
print(f"Final Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)")
# Out:
# Final Training Accuracy: 0.9762 (97.62%)
# Final Validation Accuracy: 0.8060 (80.60%)
# Final Test Accuracy: 0.8060 (80.60%)

# %%
import matplotlib.pyplot as plt

# Final accuracies
train_acc = 0.9683   # replace with your actual final training accuracy
val_acc   = 0.8290   # replace with your actual final validation accuracy
test_acc  = 0.8290   # replace with your actual final test accuracy

# Labels and values
labels = ['Training Accuracy', 'Validation Accuracy', 'Test Accuracy']
values = [train_acc, val_acc, test_acc]

# Plot bar chart
plt.figure(figsize=(6, 4))
bars = plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon'])

# Add value labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, f"{yval*100:.2f}%",
             ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.title("Final Model Accuracies")
plt.ylabel("Accuracy")
plt.ylim(0, 1.1)  # show up to 110% for clarity
plt.show()

# %%
# Save the entire model
model.save("speech_emotion_model.h5")
print("✅ Model saved as speech_emotion_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved as speech_emotion_model.h5

# %%
from tensorflow.keras.models import load_model

# Load the saved model
loaded_model = load_model("speech_emotion_model.h5")
print("✅ Model loaded successfully")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded successfully

# %%
# Save entire model (architecture + weights + optimizer state)
model.save("/content/drive/MyDrive/Multimodal_Emotion_Models/speech_emotion_model.h5")
print("✅ Model saved to Google Drive as speech_emotion_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved to Google Drive as speech_emotion_model.h5

# %%
from tensorflow.keras.models import load_model

# Load model from Drive
loaded_model = load_model("/content/drive/MyDrive/Multimodal_Emotion_Models/speech_emotion_model.h5")
print("✅ Model loaded from Google Drive")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded from Google Drive
